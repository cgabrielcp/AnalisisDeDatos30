# %% [markdown]
# # PRIMER ENTORNO PYTHON

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
# Este es un comentario inline

# %%
def funcion():
    """
        Comentario de varios lineas
        argumentos:
            - 
            - 
        resultados:
            -
            -
    """
# Out:
# '\n    Comentario de varios bloques\n    1\n    1\n    2\n    3\n    4\n'

# %%
print('3') # Comentario inline

# %%
# Validacion de numeros 
if 2 < 3:
    print('2 es menor que 3')
    print('2 es menor que 3')
    print('2 es menor que 3')
    print('2 es menor que 3')

# %% [markdown]
# # Variables
